# %%
# %matplotlib notebook

# %%
import os, sys
sys.path.append(os.path.abspath('../../main/python'))

# %%
import math
import time

import thalesians.tsa.evaluation as evaluation
import thalesians.tsa.numpyutils as npu
import thalesians.tsa.optimisation as optimisation
import thalesians.tsa.optimisation.visual as visual

import importlib
importlib.reload(evaluation)
importlib.reload(optimisation)
importlib.reload(visual)
# Out:
# <module 'thalesians.tsa.optimisation.visual' from 'S:\\dev\\tsa\\src\\main\\python\\thalesians\\tsa\\optimisation\\visual.py'>

# %%
npu.init_warnings()

# %%
def sphere_func(x, y, z):
    import time
    time.sleep(3)
    return x*x + y*y + z*z

# %%
output = optimisation.grid_search(
        sphere_func, {
                'x': [-1., -.5, 0., .5, 1.],
                'y': [-1., -.5, 0., .5, 1.],
                'z': [-1., -.5, 0., .5, 1.]
        }, evaluator=evaluation.IPyParallelEvaluator(),
        optimisation_id='sphere_func')

# %%
output
# Out:
# GridSearchOutput(param_ranges={'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, optimisation_id="sphere_func", evaluation_statuses=[Status(ready=False, work=Work(work_id=1, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -1.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 0], 'optimisation_id': 'sphere_func', 'work_id': 1}), result=None), Status(ready=False, work=Work(work_id=2, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 1], 'optimisation_id': 'sphere_func', 'work_id': 2}), result=None), Status(ready=False, work=Work(work_id=3, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 2], 'optimisation_id': 'sphere_func', 'work_id': 3}), result=None), Status(ready=False, work=Work(work_id=4, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 3], 'optimisation_id': 'sphere_func', 'work_id': 4}), result=None), Status(ready=False, work=Work(work_id=5, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 1.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 4], 'optimisation_id': 'sphere_func', 'work_id': 5}), result=None), Status(ready=False, work=Work(work_id=6, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -0.5), ('z', -1.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 1, 0], 'optimisation_id': 'sphere_func', 'work_id': 6}), result=None), Status(ready=False, work=Work(work_id=7, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -0.5), ('z', -0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 1, 1], 'optimisation_id': 'sphere_func', 'work_id': 7}), result=None), Status(ready=False, work=Work(work_id=8, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -0.5), ('z', 0.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 1, 2], 'optimisation_id': 'sphere_func', 'work_id': 8}), result=None), Status(ready=False, work=Work(work_id=9, func=<function sphere_func at 0x00000256D1A3E1E0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -0.5), ('z', 0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0. ...

# %%
visual.visualise_grid_search(output);
# Out:
# <img src="data:image/png;base64,..." width="640">
