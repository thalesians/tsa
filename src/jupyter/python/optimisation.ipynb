# %%
# %matplotlib notebook

# %%
import os, sys
sys.path.append(os.path.abspath('../../main/python'))

# %%
import math
import time

import thalesians.tsa.evaluation as evaluation
import thalesians.tsa.numpyutils as npu
import thalesians.tsa.optimisation as optimisation
import thalesians.tsa.optimisation.visual as visual

# %%
npu.init_warnings()

# %%
def sphere_func(x, y, z):
    import time
    time.sleep(1)
    return x*x + y*y + z*z

# %%
output = optimisation.grid_search(
        sphere_func, {
                'x': [-1., -.5, 0., .5, 1.],
                'y': [-1., -.5, 0., .5, 1.],
                'z': [-1., -.5, 0., .5, 1.]
        }, evaluator=evaluation.IPyParallelEvaluator(),
        optimisation_id='sphere_func')

# %%
output
# Out:
# GridSearchResult(param_ranges={'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, optimisation_id="sphere_func", evaluation_statuses=[Status(ready=True, work=Work(work_id=1, func=<function sphere_func at 0x000002A29FDD90D0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -1.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 0], 'optimisation_id': 'sphere_func', 'work_id': 1}), result=Result(work_id=1, func=<function sphere_func at 0x000002A2A01AF048>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -1.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 0], 'optimisation_id': 'sphere_func', 'work_id': 1}, evaluation_id="887f6c01626d4c848ffc5bfcea272cee", result=3.0, exception=None, start_datetime=2018-04-17 18:03:45.290476, seconds_per_call=[1.0028985972248847], hostname="DESKTOP-EFQ7TT8", pid=13040, thread_id=13040)), Status(ready=True, work=Work(work_id=2, func=<function sphere_func at 0x000002A29FDD90D0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 1], 'optimisation_id': 'sphere_func', 'work_id': 2}), result=Result(work_id=2, func=<function sphere_func at 0x000002A2A00CC950>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 1], 'optimisation_id': 'sphere_func', 'work_id': 2}, evaluation_id="d06e1a4fdfca40c5b52cca38ea3f3155", result=2.25, exception=None, start_datetime=2018-04-17 18:03:45.319830, seconds_per_call=[1.0009116996220655], hostname="DESKTOP-EFQ7TT8", pid=13204, thread_id=13204)), Status(ready=True, work=Work(work_id=3, func=<function sphere_func at 0x000002A29FDD90D0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 2], 'optimisation_id': 'sphere_func', 'work_id': 3}), result=Result(work_id=3, func=<function sphere_func at 0x000002A2A0024048>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 2], 'optimisation_id': 'sphere_func', 'work_id': 3}, evaluation_id="268e3e4f3dfa42e3bed82835c33c0290", result=2.0, exception=None, start_datetime=2018-04-17 18:03:45.386883, seconds_per_call=[0.9974174768481134], hostname="DESKTOP-EFQ7TT8", pid=30920, thread_id=30920)), Status(ready=True, work=Work(work_id=4, func=<function sphere_func at 0x000002A29FDD90D0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 3], 'optimisation_id': 'sphere_func', 'work_id': 4}), result=Result(work_id=4, func=<function sphere_func at 0x000002A29FF7B378>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.5)]), call_count=1, repeat_count=1, info ...

# %%
visual.visualise_grid_search(output, refresh_until_ready=True);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
output
# Out:
# GridSearchResult(param_ranges={'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, optimisation_id="sphere_func", evaluation_statuses=[Status(ready=True, work=Work(work_id=1, func=<function sphere_func at 0x000002A29FDD90D0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -1.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 0], 'optimisation_id': 'sphere_func', 'work_id': 1}), result=Result(work_id=1, func=<function sphere_func at 0x000002A2A01AF048>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -1.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 0], 'optimisation_id': 'sphere_func', 'work_id': 1}, evaluation_id="887f6c01626d4c848ffc5bfcea272cee", result=3.0, exception=None, start_datetime=2018-04-17 18:03:45.290476, seconds_per_call=[1.0028985972248847], hostname="DESKTOP-EFQ7TT8", pid=13040, thread_id=13040)), Status(ready=True, work=Work(work_id=2, func=<function sphere_func at 0x000002A29FDD90D0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 1], 'optimisation_id': 'sphere_func', 'work_id': 2}), result=Result(work_id=2, func=<function sphere_func at 0x000002A2A00CC950>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', -0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 1], 'optimisation_id': 'sphere_func', 'work_id': 2}, evaluation_id="d06e1a4fdfca40c5b52cca38ea3f3155", result=2.25, exception=None, start_datetime=2018-04-17 18:03:45.319830, seconds_per_call=[1.0009116996220655], hostname="DESKTOP-EFQ7TT8", pid=13204, thread_id=13204)), Status(ready=True, work=Work(work_id=3, func=<function sphere_func at 0x000002A29FDD90D0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 2], 'optimisation_id': 'sphere_func', 'work_id': 3}), result=Result(work_id=3, func=<function sphere_func at 0x000002A2A0024048>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.0)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 2], 'optimisation_id': 'sphere_func', 'work_id': 3}, evaluation_id="268e3e4f3dfa42e3bed82835c33c0290", result=2.0, exception=None, start_datetime=2018-04-17 18:03:45.386883, seconds_per_call=[0.9974174768481134], hostname="DESKTOP-EFQ7TT8", pid=30920, thread_id=30920)), Status(ready=True, work=Work(work_id=4, func=<function sphere_func at 0x000002A29FDD90D0>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.5)]), call_count=1, repeat_count=1, info={'param_ranges': {'x': [-1.0, -0.5, 0.0, 0.5, 1.0], 'y': [-1.0, -0.5, 0.0, 0.5, 1.0], 'z': [-1.0, -0.5, 0.0, 0.5, 1.0]}, 'param_names': ['x', 'y', 'z'], 'param_value_indices': [0, 0, 3], 'optimisation_id': 'sphere_func', 'work_id': 4}), result=Result(work_id=4, func=<function sphere_func at 0x000002A29FF7B378>, args=[], kwargs=OrderedDict([('x', -1.0), ('y', -1.0), ('z', 0.5)]), call_count=1, repeat_count=1, info ...

# %%
[x.ready for x in output.evaluation_statuses]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]
